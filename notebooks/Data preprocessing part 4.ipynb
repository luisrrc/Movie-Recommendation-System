# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

# %% [markdown]
# ## Web scrapping the features of 2020 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2020"

# %%
source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')

# %%
tables = soup.find_all('table',class_='wikitable sortable')

# %%
len(tables)
# Out:
# 4

# %%
type(tables[0])
# Out:
# bs4.element.Tag

# %%
df1 = pd.read_html(str(tables[0]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %% [markdown]
# Let's merge (df1, df2, df3 and df4) to create the dataframe:

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#       Opening  Opening.1                  Title  \
# 0     JANUARY          3             The Grudge
# 1     JANUARY         10             Underwater
# 2     JANUARY         10            Like a Boss
# 3     JANUARY         10          Three Christs
# 4     JANUARY         10      Inherit the Viper
# ..        ...        ...                    ...
# 265  DECEMBER         25       We Can Be Heroes
# 266  DECEMBER         25      News of the World
# 267  DECEMBER         25  One Night in Miami...
# 268  DECEMBER         25  Promising Young Woman
# 269  DECEMBER         30      Pieces of a Woman
#
#                                     Production company  \
# 0    Screen Gems / Stage 6 Films / Ghost House Pict...
# 1    20th Century Fox / TSG Entertainment / Chernin...
# 2                                   Paramount Pictures
# 3                                            IFC Films
# 4       Barry Films / Tycor International Film Company
# ..                                                 ...
# 265                     Netflix / Troublemaker Studios
# 266        Universal Pictures / Perfect World Pictures
# 267                                     Amazon Studios
# 268          Focus Features / FilmNation Entertainment
# 269                             Netflix / Bron Studios
#
#                                          Cast and crew   Ref.
# 0    Nicolas Pesce (director/screenplay); Andrea Ri...    [2]
# 1    William Eubank (director); Brian Duffield, Ada...    [3]
# 2    Miguel Arteta (director); Sam Pitman, Adam Col...    [4]
# 3    Jon Avnet (director/screenplay); Eric Nazarian...    NaN
# 4    Anthony Jerjen (director); Andrew Crabtree (sc...    [5]
# ..                                                 ...    ...
# 265  Robert Rodriguez (director/screenplay); Priyan...  [238]
# 266  Paul Greengrass (director/screenplay); Luke Da...  [239]
# 267  Regina King (director); Kemp Powers (screenpla...  [240]
# 268  Emerald Fennell (director/screenplay); Carey M...  [241]
# 269  Kornél Mundruczó (director); Kata Wéber (scree...  [242]
#
# [270 rows x 6 columns]

# %%
df_2020 = df[['Title','Cast and crew']]

# %%
df_2020
# Out:
#                      Title                                      Cast and crew
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 265       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 266      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 267  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 268  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 269      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
# [270 rows x 2 columns]

# %% [markdown]
# Now, we need to import tmdb to make the request to the api to perform the searches:

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = 'b06d85e245a457f3f655951fcf616562'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie() 
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    if not result:
      return np.NaN
    else:
      movie_id = result[0].id
      response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
      data_json = response.json()
      if data_json['genres']:
          genre_str = " " 
          for i in range(0,len(data_json['genres'])):
              genres.append(data_json['genres'][i]['name'])
          return genre_str.join(genres)
      else:
          return np.NaN

# %%
df_2020['genres'] = df_2020['Title'].map(lambda x: get_genre(str(x)))
# Out:
# <ipython-input-17-fdc91464740e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['genres'] = df_2020['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2020
# Out:
#                      Title                                      Cast and crew  \
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 265       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 266      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 267  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 268  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 269      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
#                                      genres
# 0                   Horror Mystery Thriller
# 1    Action Horror Science Fiction Thriller
# 2                                    Comedy
# 3                                     Drama
# 4                      Drama Thriller Crime
# ..                                      ...
# 265            Action Fantasy Family Comedy
# 266          Action Adventure Drama Western
# 267                                   Drama
# 268                    Thriller Crime Drama
# 269                                   Drama
#
# [270 rows x 3 columns]

# %% [markdown]
# Creating a function to get the director of each movie:

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# <ipython-input-20-bc52fe9b0c35>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(str(x)))

# %% [markdown]
# Now, we get the actor1 of the cast:

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(str(x)))
# Out:
# <ipython-input-22-42c5f763f942>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(str(x)))

# %% [markdown]
# Let's do the same with the actor2 and finally the actor3 of the cast:

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2020['actor_2_name'] = df_2020['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2020['actor_3_name'] = df_2020['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2020
# Out:
#                      Title                                      Cast and crew  \
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 265       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 266      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 267  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 268  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 269      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
#                                      genres     director_name  \
# 0                   Horror Mystery Thriller     Nicolas Pesce
# 1    Action Horror Science Fiction Thriller    William Eubank
# 2                                    Comedy     Miguel Arteta
# 3                                     Drama         Jon Avnet
# 4                      Drama Thriller Crime    Anthony Jerjen
# ..                                      ...               ...
# 265            Action Fantasy Family Comedy  Robert Rodriguez
# 266          Action Adventure Drama Western   Paul Greengrass
# 267                                   Drama       Regina King
# 268                    Thriller Crime Drama   Emerald Fennell
# 269                                   Drama  Kornél Mundruczó
#
#               actor_1_name       actor_2_name     actor_3_name
# 0       Andrea Riseborough      Demián Bichir         John Cho
# 1          Kristen Stewart     Vincent Cassel  Jessica Henwick
# 2          Tiffany Haddish         Rose Byrne      Salma Hayek
# 3             Richard Gere     Peter Dinklage   Walton Goggins
# 4            Josh Hartnett  Margarita Levieva   Chandler Riggs
# ..                     ...                ...              ...
# 265  Priyanka Chopra Jonas       Pedro Pascal    YaYa Gosselin
# 266              Tom Hanks      Helena Zengel              NaN
# 267      Kingsley Ben-Adir          Eli Goree      Aldis Hodge
# 268         Carey Mulligan         Bo Burnham      Alison Brie
# 269          Vanessa Kirby       Shia LaBeouf     Molly Parker
#
# [270 rows x 7 columns]

# %%
df_2020 = df_2020.rename(columns={'Title':'movie_title'})

# %%
new_df_2020 = df_2020.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df_2020
# Out:
#         director_name           actor_1_name       actor_2_name  \
# 0       Nicolas Pesce     Andrea Riseborough      Demián Bichir
# 1      William Eubank        Kristen Stewart     Vincent Cassel
# 2       Miguel Arteta        Tiffany Haddish         Rose Byrne
# 3           Jon Avnet           Richard Gere     Peter Dinklage
# 4      Anthony Jerjen          Josh Hartnett  Margarita Levieva
# ..                ...                    ...                ...
# 265  Robert Rodriguez  Priyanka Chopra Jonas       Pedro Pascal
# 266   Paul Greengrass              Tom Hanks      Helena Zengel
# 267       Regina King      Kingsley Ben-Adir          Eli Goree
# 268   Emerald Fennell         Carey Mulligan         Bo Burnham
# 269  Kornél Mundruczó          Vanessa Kirby       Shia LaBeouf
#
#         actor_3_name                                  genres  \
# 0           John Cho                 Horror Mystery Thriller
# 1    Jessica Henwick  Action Horror Science Fiction Thriller
# 2        Salma Hayek                                  Comedy
# 3     Walton Goggins                                   Drama
# 4     Chandler Riggs                    Drama Thriller Crime
# ..               ...                                     ...
# 265    YaYa Gosselin            Action Fantasy Family Comedy
# 266              NaN          Action Adventure Drama Western
# 267      Aldis Hodge                                   Drama
# 268      Alison Brie                    Thriller Crime Drama
# 269     Molly Parker                                   Drama
#
#                movie_title
# 0               The Grudge
# 1               Underwater
# 2              Like a Boss
# 3            Three Christs
# 4        Inherit the Viper
# ..                     ...
# 265       We Can Be Heroes
# 266      News of the World
# 267  One Night in Miami...
# 268  Promising Young Woman
# 269      Pieces of a Woman
#
# [270 rows x 6 columns]

# %%
new_df_2020['comb'] = new_df_2020['actor_1_name'] + ' ' + new_df_2020['actor_2_name'] + ' '+ new_df_2020['actor_3_name'] + ' '+ new_df_2020['director_name'] +' ' + new_df_2020['genres']

# %%
new_df_2020.isna().sum()
# Out:
# director_name     0
# actor_1_name      0
# actor_2_name      3
# actor_3_name     26
# genres            1
# movie_title       0
# comb             27
# dtype: int64

# %%
new_df_2020 = new_df_2020.dropna(how='any')

# %%
new_df_2020.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
new_df_2020['movie_title'] = new_df_2020['movie_title'].str.lower()
# Out:
# <ipython-input-35-082048944ee8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df_2020['movie_title'] = new_df_2020['movie_title'].str.lower()

# %%
new_df_2020
# Out:
#         director_name           actor_1_name       actor_2_name  \
# 0       Nicolas Pesce     Andrea Riseborough      Demián Bichir
# 1      William Eubank        Kristen Stewart     Vincent Cassel
# 2       Miguel Arteta        Tiffany Haddish         Rose Byrne
# 3           Jon Avnet           Richard Gere     Peter Dinklage
# 4      Anthony Jerjen          Josh Hartnett  Margarita Levieva
# ..                ...                    ...                ...
# 264       Pete Docter             Jamie Foxx           Tina Fey
# 265  Robert Rodriguez  Priyanka Chopra Jonas       Pedro Pascal
# 267       Regina King      Kingsley Ben-Adir          Eli Goree
# 268   Emerald Fennell         Carey Mulligan         Bo Burnham
# 269  Kornél Mundruczó          Vanessa Kirby       Shia LaBeouf
#
#         actor_3_name                                       genres  \
# 0           John Cho                      Horror Mystery Thriller
# 1    Jessica Henwick       Action Horror Science Fiction Thriller
# 2        Salma Hayek                                       Comedy
# 3     Walton Goggins                                        Drama
# 4     Chandler Riggs                         Drama Thriller Crime
# ..               ...                                          ...
# 264    Graham Norton  Family Animation Comedy Drama Music Fantasy
# 265    YaYa Gosselin                 Action Fantasy Family Comedy
# 267      Aldis Hodge                                        Drama
# 268      Alison Brie                         Thriller Crime Drama
# 269     Molly Parker                                        Drama
#
#                movie_title                                               comb
# 0               the grudge  Andrea Riseborough Demián Bichir John Cho Nico...
# 1               underwater  Kristen Stewart Vincent Cassel Jessica Henwick...
# 2              like a boss  Tiffany Haddish Rose Byrne Salma Hayek Miguel ...
# 3            three christs  Richard Gere Peter Dinklage Walton Goggins Jon...
# 4        inherit the viper  Josh Hartnett Margarita Levieva Chandler Riggs...
# ..                     ...                                                ...
# 264                   soul  Jamie Foxx Tina Fey Graham Norton Pete Docter ...
# 265       we can be heroes  Priyanka Chopra Jonas Pedro Pascal YaYa Gossel...
# 267  one night in miami...  Kingsley Ben-Adir Eli Goree Aldis Hodge Regina...
# 268  promising young woman  Carey Mulligan Bo Burnham Alison Brie Emerald ...
# 269      pieces of a woman  Vanessa Kirby Shia LaBeouf Molly Parker Kornél...
#
# [243 rows x 7 columns]

# %%
old_df = pd.read_csv('C:/Users/LUIS/OneDrive/Documentos/Movie Recommendation System/AJAX-Movie-Recommendation-System-with-Sentiment-Analysis-master/datasets/final_data.csv')

# %%
old_df
# Out:
#                director_name       actor_1_name          actor_2_name  \
# 0              James Cameron        CCH Pounder      Joel David Moore
# 1             Gore Verbinski        Johnny Depp         Orlando Bloom
# 2                 Sam Mendes    Christoph Waltz          Rory Kinnear
# 3          Christopher Nolan          Tom Hardy        Christian Bale
# 4                Doug Walker        Doug Walker            Rob Walker
# ...                      ...                ...                   ...
# 5867  Nick Bruno, Troy Quane         Will Smith           Tom Holland
# 5868            Greta Gerwig      Saoirse Ronan           Emma Watson
# 5869              Sam Mendes      George MacKay  Dean-Charles Chapman
# 5870   Destin Daniel Cretton  Michael B. Jordan            Jamie Foxx
# 5871         Chinonye Chukwu      Alfre Woodard        Wendell Pierce
#
#               actor_3_name                                    genres  \
# 0                Wes Studi           Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport                  Action Adventure Fantasy
# 2         Stephanie Sigman                 Action Adventure Thriller
# 3     Joseph Gordon-Levitt                           Action Thriller
# 4                  unknown                               Documentary
# ...                    ...                                       ...
# 5867         Rashida Jones  Animation Action Adventure Comedy Family
# 5868         Florence Pugh                             Drama Romance
# 5869           Mark Strong                 War Drama Action Thriller
# 5870           Brie Larson                       Drama Crime History
# 5871           Aldis Hodge                                     Drama
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5867                                  spies in disguise
# 5868                                       little women
# 5869                                               1917
# 5870                                         just mercy
# 5871                                           clemency
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 5867  Will Smith Tom Holland Rashida Jones Nick Brun...
# 5868  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 5869  George MacKay Dean-Charles Chapman Mark Strong...
# 5870  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 5871  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [5872 rows x 7 columns]

# %%
final_df = old_df.append(new_df_2020,ignore_index=True)

# %%
final_df
# Out:
#           director_name           actor_1_name      actor_2_name  \
# 0         James Cameron            CCH Pounder  Joel David Moore
# 1        Gore Verbinski            Johnny Depp     Orlando Bloom
# 2            Sam Mendes        Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan              Tom Hardy    Christian Bale
# 4           Doug Walker            Doug Walker        Rob Walker
# ...                 ...                    ...               ...
# 6110        Pete Docter             Jamie Foxx          Tina Fey
# 6111   Robert Rodriguez  Priyanka Chopra Jonas      Pedro Pascal
# 6112        Regina King      Kingsley Ben-Adir         Eli Goree
# 6113    Emerald Fennell         Carey Mulligan        Bo Burnham
# 6114   Kornél Mundruczó          Vanessa Kirby      Shia LaBeouf
#
#               actor_3_name                                       genres  \
# 0                Wes Studi              Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport                     Action Adventure Fantasy
# 2         Stephanie Sigman                    Action Adventure Thriller
# 3     Joseph Gordon-Levitt                              Action Thriller
# 4                  unknown                                  Documentary
# ...                    ...                                          ...
# 6110         Graham Norton  Family Animation Comedy Drama Music Fantasy
# 6111         YaYa Gosselin                 Action Fantasy Family Comedy
# 6112           Aldis Hodge                                        Drama
# 6113           Alison Brie                         Thriller Crime Drama
# 6114          Molly Parker                                        Drama
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 6110                                               soul
# 6111                                   we can be heroes
# 6112                              one night in miami...
# 6113                              promising young woman
# 6114                                  pieces of a woman
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 6110  Jamie Foxx Tina Fey Graham Norton Pete Docter ...
# 6111  Priyanka Chopra Jonas Pedro Pascal YaYa Gossel...
# 6112  Kingsley Ben-Adir Eli Goree Aldis Hodge Regina...
# 6113  Carey Mulligan Bo Burnham Alison Brie Emerald ...
# 6114  Vanessa Kirby Shia LaBeouf Molly Parker Kornél...
#
# [6115 rows x 7 columns]

# %%
final_df.to_csv('main_data.csv',index=False)

# %% [markdown]
# ## Web scrapping the features of 2021 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2021"
source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')

# %%
tables = soup.find_all('table',class_='wikitable sortable')

# %%
len(tables)
# Out:
# 4

# %%
type(tables[0])
# Out:
# bs4.element.Tag

# %%
df1 = pd.read_html(str(tables[0]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %% [markdown]
# Let's merge (df1, df2, df3 and df4) to create the dataframe:

# %%
df
# Out:
#       Opening  Opening.1                Title  \
# 0     JANUARY        1.0  Shadow in the Cloud
# 1     JANUARY       13.0      The White Tiger
# 2     JANUARY       14.0          Locked Down
# 3     JANUARY       15.0              The Dig
# 4     JANUARY       15.0     Outside the Wire
# ..        ...        ...                  ...
# 167  DECEMBER       22.0               Sing 2
# 168  DECEMBER       22.0       The King's Man
# 169  DECEMBER       22.0      Downton Abbey 2
# 170  DECEMBER       25.0               Cyrano
# 171  DECEMBER       25.0         Soggy Bottom
#
#                             Production company  \
# 0                       Vertical Entertainment
# 1                                      Netflix
# 2              HBO Max / Warner Bros. Pictures
# 3                  Netflix / Clerkenwell Films
# 4                                      Netflix
# ..                                         ...
# 167          Universal Pictures / Illumination
# 168          20th Century Studios / Marv Films
# 169            Focus Features / Carnival Films
# 170  Metro-Goldwyn-Mayer / Working Title Films
# 171        Metro-Goldwyn-Mayer / Bron Creative
#
#                                          Cast and crew  Ref   Ref.
# 0    Roseanne Liang (director/screenplay; Max Landi...  [2]    NaN
# 1    Ramin Bahrani (director/screenplay); Adarsh Go...  NaN    NaN
# 2    Doug Liman (director); Steven Knight (screenpl...  [3]    NaN
# 3    Simon Stone (director); Moira Buffini (screenp...  [4]    NaN
# 4    Mikael Håfström (director); Rob Yescombe, Rowa...  [5]    NaN
# ..                                                 ...  ...    ...
# 167  Garth Jennings (director/screenplay); Matthew ...  NaN  [132]
# 168  Matthew Vaughn (director/screenplay); Karl Gaj...  NaN   [90]
# 169  Simon Curtis (director); Julian Fellowes (scre...  NaN  [133]
# 170  Joe Wright (director); Erica Schmidt (screenpl...  NaN  [134]
# 171  Paul Thomas Anderson (director/screenplay); Co...  NaN  [135]
#
# [172 rows x 7 columns]

# %%
df_2021 = df[['Title','Cast and crew']]

# %%
df_2021
# Out:
#                    Title                                      Cast and crew
# 0    Shadow in the Cloud  Roseanne Liang (director/screenplay; Max Landi...
# 1        The White Tiger  Ramin Bahrani (director/screenplay); Adarsh Go...
# 2            Locked Down  Doug Liman (director); Steven Knight (screenpl...
# 3                The Dig  Simon Stone (director); Moira Buffini (screenp...
# 4       Outside the Wire  Mikael Håfström (director); Rob Yescombe, Rowa...
# ..                   ...                                                ...
# 167               Sing 2  Garth Jennings (director/screenplay); Matthew ...
# 168       The King's Man  Matthew Vaughn (director/screenplay); Karl Gaj...
# 169      Downton Abbey 2  Simon Curtis (director); Julian Fellowes (scre...
# 170               Cyrano  Joe Wright (director); Erica Schmidt (screenpl...
# 171         Soggy Bottom  Paul Thomas Anderson (director/screenplay); Co...
#
# [172 rows x 2 columns]

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = 'b06d85e245a457f3f655951fcf616562'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie() 
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    if not result:
      return np.NaN
    else:
      movie_id = result[0].id
      response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
      data_json = response.json()
      if data_json['genres']:
          genre_str = " " 
          for i in range(0,len(data_json['genres'])):
              genres.append(data_json['genres'][i]['name'])
          return genre_str.join(genres)
      else:
          return np.NaN

# %%
df_2021['genres'] = df_2021['Title'].map(lambda x: get_genre(str(x)))
# Out:
# <ipython-input-58-252c1cda1e49>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['genres'] = df_2021['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2021
# Out:
#                    Title                                      Cast and crew  \
# 0    Shadow in the Cloud  Roseanne Liang (director/screenplay; Max Landi...
# 1        The White Tiger  Ramin Bahrani (director/screenplay); Adarsh Go...
# 2            Locked Down  Doug Liman (director); Steven Knight (screenpl...
# 3                The Dig  Simon Stone (director); Moira Buffini (screenp...
# 4       Outside the Wire  Mikael Håfström (director); Rob Yescombe, Rowa...
# ..                   ...                                                ...
# 167               Sing 2  Garth Jennings (director/screenplay); Matthew ...
# 168       The King's Man  Matthew Vaughn (director/screenplay); Karl Gaj...
# 169      Downton Abbey 2  Simon Curtis (director); Julian Fellowes (scre...
# 170               Cyrano  Joe Wright (director); Erica Schmidt (screenpl...
# 171         Soggy Bottom  Paul Thomas Anderson (director/screenplay); Co...
#
#                               genres
# 0            Horror Action Drama War
# 1                        Crime Drama
# 2                 Comedy Crime Drama
# 3                      Drama History
# 4    Thriller Action Science Fiction
# ..                               ...
# 167    Music Animation Comedy Family
# 168          Action Adventure Comedy
# 169                            Drama
# 170     Drama Comedy History Romance
# 171                           Comedy
#
# [172 rows x 3 columns]

# %% [markdown]
# Creating a function to get the director of each movie:

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2021['director_name'] = df_2021['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# <ipython-input-61-059d9cfe3ca6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['director_name'] = df_2021['Cast and crew'].map(lambda x: get_director(str(x)))

# %% [markdown]
# Now, we get the actor1 of the cast:

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2021['actor_1_name'] = df_2021['Cast and crew'].map(lambda x: get_actor1(str(x)))
# Out:
# <ipython-input-63-fbf9a4980306>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['actor_1_name'] = df_2021['Cast and crew'].map(lambda x: get_actor1(str(x)))

# %% [markdown]
# Let's do the same with the actor2 and finally the actor3 of the cast:

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2021['actor_2_name'] = df_2021['Cast and crew'].map(lambda x: get_actor2(str(x)))
# Out:
# <ipython-input-65-597eaf6de001>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['actor_2_name'] = df_2021['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2021['actor_3_name'] = df_2021['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2021
# Out:
#                    Title                                      Cast and crew  \
# 0    Shadow in the Cloud  Roseanne Liang (director/screenplay; Max Landi...
# 1        The White Tiger  Ramin Bahrani (director/screenplay); Adarsh Go...
# 2            Locked Down  Doug Liman (director); Steven Knight (screenpl...
# 3                The Dig  Simon Stone (director); Moira Buffini (screenp...
# 4       Outside the Wire  Mikael Håfström (director); Rob Yescombe, Rowa...
# ..                   ...                                                ...
# 167               Sing 2  Garth Jennings (director/screenplay); Matthew ...
# 168       The King's Man  Matthew Vaughn (director/screenplay); Karl Gaj...
# 169      Downton Abbey 2  Simon Curtis (director); Julian Fellowes (scre...
# 170               Cyrano  Joe Wright (director); Erica Schmidt (screenpl...
# 171         Soggy Bottom  Paul Thomas Anderson (director/screenplay); Co...
#
#                               genres  \
# 0            Horror Action Drama War
# 1                        Crime Drama
# 2                 Comedy Crime Drama
# 3                      Drama History
# 4    Thriller Action Science Fiction
# ..                               ...
# 167    Music Animation Comedy Family
# 168          Action Adventure Comedy
# 169                            Drama
# 170     Drama Comedy History Romance
# 171                           Comedy
#
#                                          director_name         actor_1_name  \
# 0    Roseanne Liang (director/screenplay; Max Landi...   Chloë Grace Moretz
# 1                                        Ramin Bahrani        Adarsh Gourav
# 2                                           Doug Liman        Anne Hathaway
# 3                                          Simon Stone       Carey Mulligan
# 4                                      Mikael Håfström       Anthony Mackie
# ..                                                 ...                  ...
# 167                                     Garth Jennings  Matthew McConaughey
# 168                                     Matthew Vaughn        Ralph Fiennes
# 169                                       Simon Curtis      Hugh Bonneville
# 170                                         Joe Wright       Peter Dinklage
# 171                               Paul Thomas Anderson       Cooper Hoffman
#
#           actor_2_name           actor_3_name
# 0    Taylor John Smith           Beulah Koale
# 1        Rajkummar Rao  Priyanka Chopra Jonas
# 2     Chiwetel Ejiofor       Stephen Merchant
# 3        Ralph Fiennes             Lily James
# 4         Damson Idris          Emily Beecham
# ..                 ...                    ...
# 167  Reese Witherspoon     Scarlett Johansson
# 168     Gemma Arterton             Rhys Ifans
# 169         Jim Carter       Michelle Dockery
# 170      Haley Bennett         Ben Mendelsohn
# 171     Bradley Cooper             Alana Haim
#
# [172 rows x 7 columns]

# %%
df_2021 = df_2021.rename(columns={'Title':'movie_title'})

# %%
new_df_2021 = df_2021.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df_2021
# Out:
#                                          director_name         actor_1_name  \
# 0    Roseanne Liang (director/screenplay; Max Landi...   Chloë Grace Moretz
# 1                                        Ramin Bahrani        Adarsh Gourav
# 2                                           Doug Liman        Anne Hathaway
# 3                                          Simon Stone       Carey Mulligan
# 4                                      Mikael Håfström       Anthony Mackie
# ..                                                 ...                  ...
# 167                                     Garth Jennings  Matthew McConaughey
# 168                                     Matthew Vaughn        Ralph Fiennes
# 169                                       Simon Curtis      Hugh Bonneville
# 170                                         Joe Wright       Peter Dinklage
# 171                               Paul Thomas Anderson       Cooper Hoffman
#
#           actor_2_name           actor_3_name  \
# 0    Taylor John Smith           Beulah Koale
# 1        Rajkummar Rao  Priyanka Chopra Jonas
# 2     Chiwetel Ejiofor       Stephen Merchant
# 3        Ralph Fiennes             Lily James
# 4         Damson Idris          Emily Beecham
# ..                 ...                    ...
# 167  Reese Witherspoon     Scarlett Johansson
# 168     Gemma Arterton             Rhys Ifans
# 169         Jim Carter       Michelle Dockery
# 170      Haley Bennett         Ben Mendelsohn
# 171     Bradley Cooper             Alana Haim
#
#                               genres          movie_title
# 0            Horror Action Drama War  Shadow in the Cloud
# 1                        Crime Drama      The White Tiger
# 2                 Comedy Crime Drama          Locked Down
# 3                      Drama History              The Dig
# 4    Thriller Action Science Fiction     Outside the Wire
# ..                               ...                  ...
# 167    Music Animation Comedy Family               Sing 2
# 168          Action Adventure Comedy       The King's Man
# 169                            Drama      Downton Abbey 2
# 170     Drama Comedy History Romance               Cyrano
# 171                           Comedy         Soggy Bottom
#
# [172 rows x 6 columns]

# %%
new_df_2021['comb'] = new_df_2021['actor_1_name'] + ' ' + new_df_2021['actor_2_name'] + ' '+ new_df_2021['actor_3_name'] + ' '+ new_df_2021['director_name'] +' ' + new_df_2021['genres']

# %% [markdown]
# Looking for null values:

# %%
new_df_2021.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     3
# actor_3_name     9
# genres           1
# movie_title      1
# comb             9
# dtype: int64

# %%
new_df_2021 = new_df_2021.dropna(how='any')

# %%
new_df_2021.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
new_df_2021['movie_title'] = new_df_2021['movie_title'].str.lower()
# Out:
# <ipython-input-77-ad884b405419>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df_2021['movie_title'] = new_df_2021['movie_title'].str.lower()

# %%
new_df_2021
# Out:
#                                          director_name         actor_1_name  \
# 0    Roseanne Liang (director/screenplay; Max Landi...   Chloë Grace Moretz
# 1                                        Ramin Bahrani        Adarsh Gourav
# 2                                           Doug Liman        Anne Hathaway
# 3                                          Simon Stone       Carey Mulligan
# 4                                      Mikael Håfström       Anthony Mackie
# ..                                                 ...                  ...
# 167                                     Garth Jennings  Matthew McConaughey
# 168                                     Matthew Vaughn        Ralph Fiennes
# 169                                       Simon Curtis      Hugh Bonneville
# 170                                         Joe Wright       Peter Dinklage
# 171                               Paul Thomas Anderson       Cooper Hoffman
#
#           actor_2_name           actor_3_name  \
# 0    Taylor John Smith           Beulah Koale
# 1        Rajkummar Rao  Priyanka Chopra Jonas
# 2     Chiwetel Ejiofor       Stephen Merchant
# 3        Ralph Fiennes             Lily James
# 4         Damson Idris          Emily Beecham
# ..                 ...                    ...
# 167  Reese Witherspoon     Scarlett Johansson
# 168     Gemma Arterton             Rhys Ifans
# 169         Jim Carter       Michelle Dockery
# 170      Haley Bennett         Ben Mendelsohn
# 171     Bradley Cooper             Alana Haim
#
#                               genres          movie_title  \
# 0            Horror Action Drama War  shadow in the cloud
# 1                        Crime Drama      the white tiger
# 2                 Comedy Crime Drama          locked down
# 3                      Drama History              the dig
# 4    Thriller Action Science Fiction     outside the wire
# ..                               ...                  ...
# 167    Music Animation Comedy Family               sing 2
# 168          Action Adventure Comedy       the king's man
# 169                            Drama      downton abbey 2
# 170     Drama Comedy History Romance               cyrano
# 171                           Comedy         soggy bottom
#
#                                                   comb
# 0    Chloë Grace Moretz Taylor John Smith Beulah Ko...
# 1    Adarsh Gourav Rajkummar Rao Priyanka Chopra Jo...
# 2    Anne Hathaway Chiwetel Ejiofor Stephen Merchan...
# 3    Carey Mulligan Ralph Fiennes Lily James Simon ...
# 4    Anthony Mackie Damson Idris Emily Beecham Mika...
# ..                                                 ...
# 167  Matthew McConaughey Reese Witherspoon Scarlett...
# 168  Ralph Fiennes Gemma Arterton Rhys Ifans Matthe...
# 169  Hugh Bonneville Jim Carter Michelle Dockery Si...
# 170  Peter Dinklage Haley Bennett Ben Mendelsohn Jo...
# 171  Cooper Hoffman Bradley Cooper Alana Haim Paul ...
#
# [163 rows x 7 columns]

# %%
old_df = final_df

# %%
final_df = old_df.append(new_df_2021,ignore_index=True)

# %%
final_df.to_csv('main_data.csv',index=False)
